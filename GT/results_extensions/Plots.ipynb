# %% [markdown]
# # Learning Dynamics

# %%
#imports
import numpy as np
import pandas as pd
import pylab as pl
import math as mt
import random as rd

# %%
ticks = np.linspace(0., 1., 11) #for the y axis
NF_petrified_index = 1;
NF_modest_index = 2;
NF_fair_index = 3;
NF_greedy_index = 4;
NF_terrorist_index = 5;
F_petrified_index = 6;
F_modest_index = 7;
F_fair_index = 8;
F_greedy_index = 9;
F_terrorist_index = 10;

# %% [markdown]
# # Plot of all fractions for 1a with rho_G_0 = 0.0

# %%
data = pd.read_csv('test.txt').as_matrix()
#print(data)

# %%
# %matplotlib inline
pl.figure()
#pl.title('episode reward')
#pl.xlabel('episode')
#pl.ylabel('reward of episode')
plotrange = 50
pl.title('Evolution of ' + r'$\rho_P$' ', ' + r'$\rho_M$' ', ' + r'$\rho_F$' ' and ' + r'$\rho_G$' ' for ' + r'$\rho_{G_0} = 0.0$', fontsize = 'large')
pl.axis([-0, plotrange, -0.1, 1.1])
pl.plot([data[i][NF_petrified_index] for i in range(0,plotrange)], label ='nFunda, petrified', color = 'cyan')
pl.plot([data[i][NF_modest_index] for i in range(0,plotrange)], label ='nFunda, modest', color = 'blue')
pl.plot([data[i][NF_fair_index] for i in range(0,plotrange)], label ='nFunda, fair', color = 'orange')
pl.plot([data[i][NF_greedy_index] for i in range(0,plotrange)], label ='nFunda, greedy', color = 'black')
#pl.plot([data[i][NF_greedy_index] for i in range(0,plotrange)], label ='nFunda, greedy')

    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

pl.figure()
pl.axis([-0, plotrange, -0.1, 1.1])
pl.plot([data[i][F_fair_index] for i in range(0,plotrange)], label ='Funda, fair', color = 'orange')
pl.plot([data[i][F_greedy_index] for i in range(0,plotrange)], label ='Funda, greedy', color = 'magenta' )
pl.plot([data[i][F_terrorist_index] for i in range(0,plotrange)], label ='Funda, terrorist', color = 'red')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

# %% [markdown]
# # figure 1a: comparison for different values of rho_G_0

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.0 (closest to paper's plot)

# %%
data_1a_5 = pd.read_csv('test.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure(figsize=(10, 6))
plotrange = 50
pl.axis([0, plotrange, -.01, 1])
nFunda_fair_index = 3;
pl.yticks(ticks);
#pl.plot([data_1a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$', marker = '.')

pl.plot([data_1a_5[i][NF_petrified_index] for i in range(0,plotrange)], label =r'$\rho_{P}$', marker = '.')
pl.plot([data_1a_5[i][NF_modest_index] for i in range(0,plotrange)], label =r'$\rho_{M}$', marker = '.')
pl.plot([data_1a_5[i][NF_fair_index] for i in range(0,plotrange)], label =r'$\rho_{F}$', marker = '.')
pl.plot([data_1a_5[i][NF_greedy_index] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}}$', marker = '.')

#pl.title('Evolution of ' + r'$\rho_F$' ' for ' + r'$\rho_{G_0} = 0.0$', fontsize = 'large')
pl.title('Evolution of ' + r'$\rho_P$' ', ' + r'$\rho_M$' ', ' + r'$\rho_F$' ' and ' + r'$\rho_\mathfrak{J}$' ' for ' + r'$\rho_{F_0} = 0.50$' ', ' + r'$\rho_{\mathfrak{J}_0} = 0.05$' ', ' + r'$x_{G} = 0.6$' ', ' + r'$\sigma_{\mathfrak{J}_0} = 0.2$' ', ' + r'$\sigma_T = 0.2$' ' and ' + r'$\omega = 0.9$' , fontsize = 'large')
pl.ylabel(r'$\rho$' ' fractions')
pl.xlabel('generation')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

########################################################
###################### NEW FIGURE ######################
########################################################

pl.figure(figsize=(10, 6))
plotrange = 50
pl.axis([0, plotrange, -.01, 1])
nFunda_fair_index = 3;
pl.yticks(ticks);

pl.plot([data_1a_5[i][F_modest_index] for i in range(0,plotrange)], label =r'$\sigma_{M}$', marker = '.')
pl.plot([data_1a_5[i][F_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{F}$', marker = '.')
pl.plot([data_1a_5[i][F_greedy_index] for i in range(0,plotrange)], label =r'$\sigma_{\mathfrak{J}}$', marker = '.')
pl.plot([data_1a_5[i][F_terrorist_index] for i in range(0,plotrange)], label =r'$\sigma_{T}$', marker = '.')

#pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$',marker = '.')
#pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$',marker = '.')
#pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$',marker = '.')

pl.title('Evolution of ' + r'$\sigma_M$' ', ' + r'$\sigma_F$' ', ' + r'$\sigma_\mathfrak{J}$' ' and ' + r'$\sigma_T$' ' for ' + r'$\rho_{F_0} = 0.5$' ', ' + r'$\rho_{\mathfrak{J}_0} = 0.05$' ', ' + r'$x_{G} = 0.6$' ', ' + r'$\sigma_{\mathfrak{J}_0} = 0.2$' ', ' + r'$\sigma_T = 0.2$' ' and ' + r'$\omega = 0.9$' , fontsize = 'large')
pl.ylabel(r'$\rho$' ' fractions')
pl.xlabel('generation')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.1

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.2

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.3

# %% [markdown]
# # figure 1d

# %%
data_1d_5 = pd.read_csv('1d_rhoG0/1d_sigmaG5_rhoG0.txt').as_matrix()
data_1d_6 = pd.read_csv('1d_rhoG0/1d_sigmaG6_rhoG0.txt').as_matrix()
data_1d_7 = pd.read_csv('1d_rhoG0/1d_sigmaG7_rhoG0.txt').as_matrix()
data_1d_8 = pd.read_csv('1d_rhoG0/1d_sigmaG8_rhoG0.txt').as_matrix()
data_1d_9 = pd.read_csv('1d_rhoG0/1d_sigmaG9_rhoG0.txt').as_matrix()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-18-7391d1878e32> in <module>()
# ----> 1 data_1d_5 = pd.read_csv('1d_rhoG0/1d_sigmaG5_rhoG0.txt').as_matrix()
#       2 data_1d_6 = pd.read_csv('1d_rhoG0/1d_sigmaG6_rhoG0.txt').as_matrix()
#       3 data_1d_7 = pd.read_csv('1d_rhoG0/1d_sigmaG7_rhoG0.txt').as_matrix()
#       4 data_1d_8 = pd.read_csv('1d_rhoG0/1d_sigmaG8_rhoG0.txt').as_matrix()
#       5 data_1d_9 = pd.read_csv('1d_rhoG0/1d_sigmaG9_rhoG0.txt').as_matrix()
#
# ...

# %%
#%matplotlib inline
pl.figure(figsize=(10, 6))
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.yticks(ticks);
pl.plot([data_1d_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$', marker = '.')
pl.plot([data_1d_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$', marker = '.')
pl.plot([data_1d_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$', marker = '.')
pl.plot([data_1d_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$', marker = '.')
pl.plot([data_1d_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$', marker = '.')
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 1d: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
#pl.show()
pl.savefig('1d.pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a120f14bb764> in <module>()
#       5 nFunda_fair_index = 2;
#       6 pl.yticks(ticks);
# ----> 7 pl.plot([data_1d_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$', marker = '.')
#       8 pl.plot([data_1d_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$', marker = '.')
#       9 pl.plot([data_1d_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$', marker = '.')
#
# NameError: name 'data_1d_5' is not defined

# %% [markdown]
# # figure 2a

# %%
data_2a_5 = pd.read_csv('2a_rhoG0/2a_sigmaG5_rhoG0.txt').as_matrix()
data_2a_6 = pd.read_csv('2a_rhoG0/2a_sigmaG6_rhoG0.txt').as_matrix()
data_2a_7 = pd.read_csv('2a_rhoG0/2a_sigmaG7_rhoG0.txt').as_matrix()
data_2a_8 = pd.read_csv('2a_rhoG0/2a_sigmaG8_rhoG0.txt').as_matrix()
data_2a_9 = pd.read_csv('2a_rhoG0/2a_sigmaG9_rhoG0.txt').as_matrix()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-20-ceca4ea5c8ef> in <module>()
# ----> 1 data_2a_5 = pd.read_csv('2a_rhoG0/2a_sigmaG5_rhoG0.txt').as_matrix()
#       2 data_2a_6 = pd.read_csv('2a_rhoG0/2a_sigmaG6_rhoG0.txt').as_matrix()
#       3 data_2a_7 = pd.read_csv('2a_rhoG0/2a_sigmaG7_rhoG0.txt').as_matrix()
#       4 data_2a_8 = pd.read_csv('2a_rhoG0/2a_sigmaG8_rhoG0.txt').as_matrix()
#       5 data_2a_9 = pd.read_csv('2a_rhoG0/2a_sigmaG9_rhoG0.txt').as_matrix()
#
# ...

# %%
#%matplotlib inline
pl.figure(figsize=(10, 6))
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.yticks(ticks);
pl.plot([data_2a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$', marker = '.')
pl.plot([data_2a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$', marker = '.')
pl.plot([data_2a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$', marker = '.')
pl.plot([data_2a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$', marker = '.')
pl.plot([data_2a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$', marker = '.')
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 2a: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
#pl.show()
pl.savefig('2a.pdf', bbox_inches='tight')

# %% [markdown]
# # figure 2d

# %%
data_2d_5 = pd.read_csv('2d_rhoG0/2d_sigmaG5_rhoG0.txt').as_matrix()
data_2d_6 = pd.read_csv('2d_rhoG0/2d_sigmaG6_rhoG0.txt').as_matrix()
data_2d_7 = pd.read_csv('2d_rhoG0/2d_sigmaG7_rhoG0.txt').as_matrix()
data_2d_8 = pd.read_csv('2d_rhoG0/2d_sigmaG8_rhoG0.txt').as_matrix()
data_2d_9 = pd.read_csv('2d_rhoG0/2d_sigmaG9_rhoG0.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure(figsize=(10, 6))
plotrange = 20
pl.axis([0, plotrange, 0, 1])
pl.yticks(ticks);
nFunda_fair_index = 2;
pl.plot([data_2d_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$', marker = '.')
pl.plot([data_2d_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$', marker = '.')
pl.plot([data_2d_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$', marker = '.')
pl.plot([data_2d_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$', marker = '.')
pl.plot([data_2d_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$', marker = '.')
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 2d: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
#pl.show()
pl.savefig('2d.pdf', bbox_inches='tight')

# %% [markdown]
# # figure 3a

# %%
data = pd.read_csv('3a.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure(figsize=(10, 6))
pl.title('figure 3a: Evolution of General Population\'s strategies')
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 50
pl.axis([0, plotrange, 0, 1.1])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$', marker = '.')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$', marker = '.')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$', marker = '.')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
#pl.show()
pl.savefig('3a_changed_update_order.pdf', bbox_inches='tight')

# %% [markdown]
# # figure 3b

# %%
data = pd.read_csv('3b.txt').as_matrix()

# %%
# %matplotlib inline
pl.figure(figsize=(10, 6))
pl.title('figure 3b: Evolution of General Population\'s strategies')
pl.yticks(ticks);
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 50
pl.axis([0, plotrange, 0, 1])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$',marker = '.')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$', marker = '.')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$', marker = '.')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
#pl.show()
pl.savefig('3b_changed_update_order.pdf', bbox_inches='tight')

# %% [markdown]
# # figure 3c

# %%
data = pd.read_csv('3c.txt').as_matrix()

# %%
# %matplotlib inline
pl.figure(figsize=(10, 6))
pl.yticks(ticks);
pl.title('figure 3c: Evolution of General Population\'s strategies')
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 50
pl.axis([0, plotrange, 0, 1.01])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$',marker = '.')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$',marker = '.')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$',marker = '.')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'large', loc='center right', bbox_to_anchor=(1.1, .6))
#pl.show()
pl.savefig('3c.pdf', bbox_inches='tight')
