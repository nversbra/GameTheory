# %% [markdown]
# # Learning Dynamics

# %%
#imports
import numpy as np
import pandas as pd
import pylab as pl
import math as mt
import random as rd

# %% [markdown]
# # Plot of all fractions for 1a with rho_G_0 = 0.0

# %%
data = pd.read_csv('1a_rhoG0/1a_sigmaG5_rhoG0.txt').as_matrix()
#print(data)

# %%
pl.figure()
#pl.title('episode reward')
#pl.xlabel('episode')
#pl.ylabel('reward of episode')
plotrange = 40
pl.axis([-0, plotrange, -0.1, 1.1])
pl.plot([data[i][1] for i in range(0,plotrange)], label ='nFunda, modest')
pl.plot([data[i][2] for i in range(0,plotrange)], label ='nFunda, fair')
pl.plot([data[i][3] for i in range(0,plotrange)], label ='nFunda, greedy')
pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

# %% [markdown]
# # figure 1a: comparison for different values of rho_G_0

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.0 (closest to paper's plot)

# %%
data_1a_5 = pd.read_csv('1a_rhoG0/1a_sigmaG5_rhoG0.txt').as_matrix()
data_1a_6 = pd.read_csv('1a_rhoG0/1a_sigmaG6_rhoG0.txt').as_matrix()
data_1a_7 = pd.read_csv('1a_rhoG0/1a_sigmaG7_rhoG0.txt').as_matrix()
data_1a_8 = pd.read_csv('1a_rhoG0/1a_sigmaG8_rhoG0.txt').as_matrix()
data_1a_9 = pd.read_csv('1a_rhoG0/1a_sigmaG9_rhoG0.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
plotrange = 40
pl.axis([0, plotrange, -.01, 1])
nFunda_fair_index = 2;
pl.plot([data_1a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$')
pl.plot([data_1a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$')
pl.plot([data_1a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$')
pl.plot([data_1a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$')
pl.plot([data_1a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('Evolution of ' + r'$\rho_F$' ' for ' + r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.1

# %%
data_1a_5 = pd.read_csv('1a_rhoG1/1a_sigmaG5_rhoG1.txt').as_matrix()
data_1a_6 = pd.read_csv('1a_rhoG1/1a_sigmaG6_rhoG1.txt').as_matrix()
data_1a_7 = pd.read_csv('1a_rhoG1/1a_sigmaG7_rhoG1.txt').as_matrix()
data_1a_8 = pd.read_csv('1a_rhoG1/1a_sigmaG8_rhoG1.txt').as_matrix()
data_1a_9 = pd.read_csv('1a_rhoG1/1a_sigmaG9_rhoG1.txt').as_matrix()

# %%
# %matplotlib inline
pl.figure()
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_1a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.5')
pl.plot([data_1a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.6')
pl.plot([data_1a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.7')
pl.plot([data_1a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.8')
pl.plot([data_1a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.9')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('Evolution of rho_F for rho_G_0 = 0.1')
pl.ylabel('rho_F')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.2

# %%
data_1a_5 = pd.read_csv('1a_rhoG2/1a_sigmaG5_rhoG2.txt').as_matrix()
data_1a_6 = pd.read_csv('1a_rhoG2/1a_sigmaG6_rhoG2.txt').as_matrix()
data_1a_7 = pd.read_csv('1a_rhoG2/1a_sigmaG7_rhoG2.txt').as_matrix()
data_1a_8 = pd.read_csv('1a_rhoG2/1a_sigmaG8_rhoG2.txt').as_matrix()
data_1a_9 = pd.read_csv('1a_rhoG2/1a_sigmaG9_rhoG2.txt').as_matrix()

# %%
# %matplotlib inline
pl.figure()
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_1a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.5')
pl.plot([data_1a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.6')
pl.plot([data_1a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.7')
pl.plot([data_1a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.8')
pl.plot([data_1a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.9')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('Evolution of rho_F for rho_G_0 = 0.2')
pl.ylabel('rho_F')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# ## figure 1a for rho_G_0 = 0.3

# %%
data_1a_5 = pd.read_csv('1a_rhoG3/1a_sigmaG5_rhoG3.txt').as_matrix()
data_1a_6 = pd.read_csv('1a_rhoG3/1a_sigmaG6_rhoG3.txt').as_matrix()
data_1a_7 = pd.read_csv('1a_rhoG3/1a_sigmaG7_rhoG3.txt').as_matrix()
data_1a_8 = pd.read_csv('1a_rhoG3/1a_sigmaG8_rhoG3.txt').as_matrix()
data_1a_9 = pd.read_csv('1a_rhoG3/1a_sigmaG9_rhoG3.txt').as_matrix()

# %%
# %matplotlib inline
pl.figure()
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_1a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.5')
pl.plot([data_1a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.6')
pl.plot([data_1a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.7')
pl.plot([data_1a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.8')
pl.plot([data_1a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label ='sigma_G_0 = 0.9')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('Evolution of rho_F for rho_G_0 = 0.3')
pl.ylabel('rho_F')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# # figure 1d

# %%
data_1d_5 = pd.read_csv('1d_rhoG0/1d_sigmaG5_rhoG0.txt').as_matrix()
data_1d_6 = pd.read_csv('1d_rhoG0/1d_sigmaG6_rhoG0.txt').as_matrix()
data_1d_7 = pd.read_csv('1d_rhoG0/1d_sigmaG7_rhoG0.txt').as_matrix()
data_1d_8 = pd.read_csv('1d_rhoG0/1d_sigmaG8_rhoG0.txt').as_matrix()
data_1d_9 = pd.read_csv('1d_rhoG0/1d_sigmaG9_rhoG0.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
plotrange = 40
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_1d_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$')
pl.plot([data_1d_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$')
pl.plot([data_1d_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$')
pl.plot([data_1d_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$')
pl.plot([data_1d_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 1d: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# # figure 2a

# %%
data_2a_5 = pd.read_csv('2a_rhoG0/2a_sigmaG5_rhoG0.txt').as_matrix()
data_2a_6 = pd.read_csv('2a_rhoG0/2a_sigmaG6_rhoG0.txt').as_matrix()
data_2a_7 = pd.read_csv('2a_rhoG0/2a_sigmaG7_rhoG0.txt').as_matrix()
data_2a_8 = pd.read_csv('2a_rhoG0/2a_sigmaG8_rhoG0.txt').as_matrix()
data_2a_9 = pd.read_csv('2a_rhoG0/2a_sigmaG9_rhoG0.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
plotrange = 20
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_2a_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$')
pl.plot([data_2a_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$')
pl.plot([data_2a_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$')
pl.plot([data_2a_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$')
pl.plot([data_2a_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 2a: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# # figure 2d

# %%
data_2d_5 = pd.read_csv('2d_rhoG0/2d_sigmaG5_rhoG0.txt').as_matrix()
data_2d_6 = pd.read_csv('2d_rhoG0/2d_sigmaG6_rhoG0.txt').as_matrix()
data_2d_7 = pd.read_csv('2d_rhoG0/2d_sigmaG7_rhoG0.txt').as_matrix()
data_2d_8 = pd.read_csv('2d_rhoG0/2d_sigmaG8_rhoG0.txt').as_matrix()
data_2d_9 = pd.read_csv('2d_rhoG0/2d_sigmaG9_rhoG0.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
plotrange = 20
pl.axis([0, plotrange, 0, 1])
nFunda_fair_index = 2;
pl.plot([data_2d_5[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.5$')
pl.plot([data_2d_6[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.6$')
pl.plot([data_2d_7[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.7$')
pl.plot([data_2d_8[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.8$')
pl.plot([data_2d_9[i][nFunda_fair_index] for i in range(0,plotrange)], label =r'$\sigma_{G_0} = 0.9$')
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.title('figure 2d: Evolution of '+r'$\rho_F$'+' for '+r'$\rho_{G_0} = 0.0$')
pl.ylabel(r'$\rho_F$')
pl.xlabel('generation')
pl.show()

# %% [markdown]
# # figure 3a

# %%
data = pd.read_csv('3a.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
pl.title('figure 3a: Evolution of General Population\'s strategies')
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 50
pl.axis([0, plotrange, 0, 1])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

# %% [markdown]
# # figure 3b

# %%
data = pd.read_csv('3b.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
pl.title('figure 3b: Evolution of General Population\'s strategies')
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 100
pl.axis([0, plotrange, 0, 1])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()

# %% [markdown]
# # figure 3c

# %%
data = pd.read_csv('3c.txt').as_matrix()

# %%
#%matplotlib inline
pl.figure()
pl.title('figure 3c: Evolution of General Population\'s strategies')
#pl.title('episode reward')
pl.xlabel('generation')
pl.ylabel(r'$\rho$' + ' fractions')
plotrange = 100
pl.axis([0, plotrange, 0, 1])
pl.plot([data[i][1] for i in range(0,plotrange)], label =r'$\rho_{M_0}$')
pl.plot([data[i][2] for i in range(0,plotrange)], label =r'$\rho_{F_0}$')
pl.plot([data[i][3] for i in range(0,plotrange)], label =r'$\rho_{\mathfrak{J}_0}$')
#pl.plot([data[i][4] for i in range(0,plotrange)], label ='Funda, modest')
#pl.plot([data[i][5] for i in range(0,plotrange)], label ='Funda, fair')
#pl.plot([data[i][6] for i in range(0,plotrange)], label ='Funda, greedy')
    
#pl.plot([0,repeats],[qstar,qstar], c='black', label = 'Q*ai',linestyle='dashed')
pl.legend().draggable()
pl.legend(fontsize = 'small', loc='center right', bbox_to_anchor=(1.1, .6))
pl.show()
